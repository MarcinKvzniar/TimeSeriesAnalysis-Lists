# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('monthly_in_situ_co2_mlo.csv',
                 skiprows=61,
                 usecols=['Yr', 'Mn', 'CO2'],
                 skipinitialspace=True)
df.drop([0, 1], inplace=True)
df
# Out:
#          Yr    Mn     CO2
# 2    1958.0   1.0  -99.99
# 3    1958.0   2.0  -99.99
# 4    1958.0   3.0  315.71
# 5    1958.0   4.0  317.45
# 6    1958.0   5.0  317.51
# ..      ...   ...     ...
# 801  2024.0   8.0  -99.99
# 802  2024.0   9.0  -99.99
# 803  2024.0  10.0  -99.99
# 804  2024.0  11.0  -99.99
# 805  2024.0  12.0  -99.99
#
# [804 rows x 3 columns]

# %%
df['Yr'] = df['Yr'].astype(int).astype(str)
df['Mn'] = df['Mn'].astype(int).astype(str)
df
# Out:
#        Yr  Mn     CO2
# 2    1958   1  -99.99
# 3    1958   2  -99.99
# 4    1958   3  315.71
# 5    1958   4  317.45
# 6    1958   5  317.51
# ..    ...  ..     ...
# 801  2024   8  -99.99
# 802  2024   9  -99.99
# 803  2024  10  -99.99
# 804  2024  11  -99.99
# 805  2024  12  -99.99
#
# [804 rows x 3 columns]

# %%
df.index = pd.to_datetime(df['Yr'] + '-' + df['Mn'])

# %%
df.index.freq = 'MS'

# %%
df = df.drop(columns=['Yr', 'Mn'])
df
# Out:
#                CO2
# 1958-01-01  -99.99
# 1958-02-01  -99.99
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.51
# ...            ...
# 2024-08-01  -99.99
# 2024-09-01  -99.99
# 2024-10-01  -99.99
# 2024-11-01  -99.99
# 2024-12-01  -99.99
#
# [804 rows x 1 columns]

# %%
df['CO2'] = pd.to_numeric(df['CO2'], errors='coerce')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = df.replace(-99.99, np.nan)

# %%
df.isna().sum()
# Out:
# CO2    16
# dtype: int64

# %%
df = df.fillna(method='bfill')
# Out:
# C:\Users\Marcin\AppData\Local\Temp\ipykernel_19812\3449235937.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='bfill')

# %%
df.dropna(inplace=True)
df
# Out:
#                CO2
# 1958-01-01  315.71
# 1958-02-01  315.71
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.51
# ...            ...
# 2023-11-01  420.12
# 2023-12-01  421.65
# 2024-01-01  422.62
# 2024-02-01  424.35
# 2024-03-01  425.22
#
# [795 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >
